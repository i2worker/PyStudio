# %% [markdown]
# ## 第12章 武装飞船

# %% [markdown]
# [详见代码请查看：proj/alien](proj/alien)
#
# - [game.py](proj/alien/game.py)：**主文件**，包含AlienInvasion类，负责处理游戏主循环。
# - [ship.py](proj/alien/ship.py)：包含Ship类，负责管理飞船。
# - [bullet.py](proj/alien/bullet.py)：包含Bullet类，负责管理子弹。
# - [alien.py](proj/alien/alien.py)：包含Alien类，负责管理外星人舰队。
# - [score.py](proj/alien/score.py)：包含Score类，负责管理游戏得分等信息显示。
# - [stats.py](proj/alien/stats.py)：包含GameStats类，负责跟踪游戏统计信息。
# - [button.py](proj/alien/button.py)：包含Button类，负责管理游戏按钮。
# - [settings.py](proj/alien/settings.py)：包含Settings类，负责管理游戏的所有配置值。

# %%
# 切换至游戏目录
# %cd -q proj/alien

# 启动游戏
# !python game.py

# 切换回主目录
# %cd -q ../..
