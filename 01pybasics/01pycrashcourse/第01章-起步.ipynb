# %% [markdown]
# ## 第1章　起步

# %% [markdown]
# - 本章主要介绍Windows、Linux、macOS系统下，如何安装Python环境、VSCode编辑器。
#
# - 个人推荐使用**Anaconda**安装编程环境、在**VSCode**中安装**Juypter**插件，更好的学习Python编程。
#
# - 随书补充资料：[ituring.cn/book/3038](https://ituring.cn/book/3038)，包括安装说明、更新、练习答案、数据下载方法、速查表、PPT课件、源代码文件、学习路线图等。
